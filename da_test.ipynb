# %%
import pandas as pd
import numpy as np
import datetime

# %%
import data_process_tools as dpt
import data_analysis_tools as dat
import auto_data_analysis as ada

import importlib
importlib.reload(ada)
importlib.reload(dpt)
importlib.reload(dat)
# Out:
# <module 'data_analysis_tools' from '/Users/andrewmo/Documents/Docs_Jupiter/Library/1_Personal/autoDA/data_analysis_tools.py'>

# %%
# file_name = 'data/feature_0.csv'
# file_name = 'data/energydata_complete.csv'
# file_name = 'data/job.csv'
file_name = 'data/shanghai-ranking_2023.csv'

feature_data = pd.read_csv(file_name)

# %%
da = ada.DataAnalysis(feature_data)
# Out:
# Instance initiated. Running...
#
# Data cleaning...
#     before: (1000, 19)
#     after: (546, 19)
#
# Basic property checking...
#     column dtypes: numeric: 9, object: 10, datetime: 0, bool: 0, other: 0,
#
# Calculating data statistics...
#
# Run Completed
#     Property created: dtypes, mean, std_values,
#     Visual options:
#         .visual_distribution()

# %%
da.visual_distribution()
